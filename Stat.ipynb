# %%
from google.cloud.sql.connector import Connector
import sqlalchemy
from sqlalchemy import text, delete

# %%
project_id = "true-source-329719"
region = "us-central1"
instance_name = "hw5-database"
pw = 'my_password'

# %%
instance_connection_name = f"{project_id}:{region}:{instance_name}"
print(f"Your instance connection name is: {instance_connection_name}")
DB_USER = "wei"
DB_PASS = 'my_password'
DB_NAME = "hw5"
# Out:
# Your instance connection name is: true-source-329719:us-central1:hw5-database

# %%
# initialize Connector object
connector = Connector()

# function to return the database connection object
def getconn():
    conn = connector.connect(
        instance_connection_name,
        "pymysql",
        user=DB_USER,
        password=DB_PASS,
        db=DB_NAME
    )
    return conn

pool = sqlalchemy.create_engine(
    "mysql+pymysql://",
    creator=getconn,
)

# %%
with pool.connect() as db_conn:
    successful = db_conn.execute(text("SELECT COUNT(*) FROM IP_TABLE")).fetchall()
    unsuccessful = db_conn.execute(text("SELECT COUNT(*) FROM ERROR_TABLE")).fetchall()
    ban_country = db_conn.execute(text(
            "SELECT COUNT(*) FROM BAN_TABLE WHERE is_banned='TRUE' ")).fetchall()
    
    male = db_conn.execute(text(
        "SELECT COUNT(*) FROM IP_TABLE WHERE gender='Male' ")).fetchall()
    female = db_conn.execute(text(
        "SELECT COUNT(*) FROM IP_TABLE WHERE gender='Female' ")).fetchall()
    top_country = db_conn.execute(text(
        "SELECT country, COUNT(country) as freq FROM IP_TABLE GROUP BY country ORDER BY freq DESC LIMIT 5")).fetchall()

# %%
print(f"number of successful requests: {successful}")
# Out:
# number of successful requests: [(11712,)]

# %%
print(f"number of unsuccessful requests: {unsuccessful}")
# Out:
# number of unsuccessful requests: [(110897,)]

# %%
print(f"number of requests from ban countries: {ban_country}")
# Out:
# number of requests from ban countries: [(5635,)]

# %%
print(f"number of male requests: {male}")
# Out:
# number of male requests: [(5840,)]

# %%
print(f"number of female requests: {female}")
# Out:
# number of female requests: [(5872,)]

# %%
print(f"number of top country: {top_country}")
# Out:
# number of top country: [('Gabon', 83), ('Albania', 82), ('Kosovo', 81), ('Vietnam', 81), ('Dominica', 81)]

# %%
db_conn = pool.connect()
top_age = db_conn.execute(text(
    "SELECT age, count(age) as freq_age from IP_TABLE GROUP BY age ORDER BY freq_age DESC LIMIT 5")).fetchall()
top_income = db_conn.execute(text(
    "SELECT income, count(income) as freq_income from IP_TABLE GROUP BY income ORDER BY freq_income DESC LIMIT 5")).fetchall()

# %%
print(f"number of top age: {top_age}")
# Out:
# number of top age: [('26-35', 1610), ('76+', 1550), ('17-25', 1548), ('66-75', 1527), ('46-55', 1525)]

# %%
print(f"number of top income: {top_income}")
# Out:
# number of top income: [('100k-150k', 1628), ('250k+', 1587), ('150k-250k', 1559), ('20k-40k', 1544), ('40k-60k', 1510)]
# ['true-source-329719:us-central1:hw5-database']: An error occurred while performing refresh. Scheduling another refresh attempt immediately
# Traceback (most recent call last):
#   File "c:\Users\16178\AppData\Local\Programs\Python\Python310\lib\site-packages\google\cloud\sql\connector\instance.py", line 389, in _refresh_task
#     refresh_data = await refresh_task
#   File "c:\Users\16178\AppData\Local\Programs\Python\Python310\lib\site-packages\google\cloud\sql\connector\instance.py", line 326, in _perform_refresh
#     ephemeral_cert = await ephemeral_task
#   File "c:\Users\16178\AppData\Local\Programs\Python\Python310\lib\site-packages\google\cloud\sql\connector\refresh_utils.py", line 201, in _get_ephemeral
#     resp = await client_session.post(
# ...
